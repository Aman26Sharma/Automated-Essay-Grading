# %%
import numpy as np
import pandas as pd

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
# Importing the data

# %%
df = pd.read_csv('training_set_rel3.tsv', delimiter='\t', quoting=3, encoding='ISO-8859-1')

# %%
df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  "Dear local newspaper, I think effects compute...
# 1         2          1  "Dear @CAPS1 @CAPS2, I believe that using comp...
# 2         3          1  "Dear, @CAPS1 @CAPS2 @CAPS3 More and more peop...
# 3         4          1  "Dear Local Newspaper, @CAPS1 I have found tha...
# 4         5          1  "Dear @LOCATION1, I know having computers has ...
#
#    rater1_domain1  rater2_domain1  rater3_domain1  domain1_score  \
# 0               4               4             NaN              8
# 1               5               4             NaN              9
# 2               4               3             NaN              7
# 3               5               5             NaN             10
# 4               4               4             NaN              8
#
#    rater1_domain2  rater2_domain2  domain2_score  ...  rater2_trait3  \
# 0             NaN             NaN            NaN  ...            NaN
# 1             NaN             NaN            NaN  ...            NaN
# 2             NaN             NaN            NaN  ...            NaN
# 3             NaN             NaN            NaN  ...            NaN
# 4             NaN             NaN            NaN  ...            NaN
#
#    rater2_trait4  rater2_trait5  rater2_trait6  rater3_trait1  rater3_trait2  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    rater3_trait3  rater3_trait4  rater3_trait5  rater3_trait6
# 0            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN
#
# [5 rows x 28 columns]

# %%
df = df.dropna(axis=1)
df.head()
# Out:
#    essay_id  essay_set                                              essay  \
# 0         1          1  "Dear local newspaper, I think effects compute...
# 1         2          1  "Dear @CAPS1 @CAPS2, I believe that using comp...
# 2         3          1  "Dear, @CAPS1 @CAPS2 @CAPS3 More and more peop...
# 3         4          1  "Dear Local Newspaper, @CAPS1 I have found tha...
# 4         5          1  "Dear @LOCATION1, I know having computers has ...
#
#    rater1_domain1  rater2_domain1  domain1_score
# 0               4               4              8
# 1               5               4              9
# 2               4               3              7
# 3               5               5             10
# 4               4               4              8

# %%
X = df['essay']
X.head()
# Out:
# 0    "Dear local newspaper, I think effects compute...
# 1    "Dear @CAPS1 @CAPS2, I believe that using comp...
# 2    "Dear, @CAPS1 @CAPS2 @CAPS3 More and more peop...
# 3    "Dear Local Newspaper, @CAPS1 I have found tha...
# 4    "Dear @LOCATION1, I know having computers has ...
# Name: essay, dtype: object

# %%
type(X)
# Out:
# pandas.core.series.Series

# %%
y = df['domain1_score']
y.head()
# Out:
# 0     8
# 1     9
# 2     7
# 3    10
# 4     8
# Name: domain1_score, dtype: int64

# %%
# Data Preprocessing

# %%
import re
import nltk

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\amans\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\amans\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\amans\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def preprocess(X):
    
    corpus = []
    for i in range(0,len(X)):
        essay = re.sub('[^a-zA-Z]',' ',X[i]) # Removes every char except [^a-zA-Z] 
        essay = essay.lower() # All characters in lower
        essay = essay.split() # split all the words
        lemmatizer = WordNetLemmatizer() # Lemmatize every word
        essay = [lemmatizer.lemmatize(word) for word in essay if not word in set(stopwords.words('english'))]
        essay = ' '.join(essay) # Join all the words
        corpus.append(essay)
        
    sent = []
    for i in range(len(corpus)):
        sent.append(nltk.sent_tokenize(corpus[i])) # Change all para into list of sentences
        
    word = []
    for i in range(len(sent)):
        word.append(nltk.word_tokenize(sent[i][0])) # Change all the sent into list of words
        
    return word

# %%
word = preprocess(X)

# %%
word[0]
# Out:
# ['dear',
#  'local',
#  'newspaper',
#  'think',
#  'effect',
#  'computer',
#  'people',
#  'great',
#  'learning',
#  'skill',
#  'affect',
#  'give',
#  'u',
#  'time',
#  'chat',
#  'friend',
#  'new',
#  'people',
#  'help',
#  'u',
#  'learn',
#  'globe',
#  'astronomy',
#  'keep',
#  'u',
#  'troble',
#  'thing',
#  'dont',
#  'think',
#  'would',
#  'feel',
#  'teenager',
#  'always',
#  'phone',
#  'friend',
#  'ever',
#  'time',
#  'chat',
#  'friend',
#  'buisness',
#  'partner',
#  'thing',
#  'well',
#  'new',
#  'way',
#  'chat',
#  'computer',
#  'plenty',
#  'site',
#  'internet',
#  'organization',
#  'organization',
#  'cap',
#  'facebook',
#  'myspace',
#  'ect',
#  'think',
#  'setting',
#  'meeting',
#  'bos',
#  'computer',
#  'teenager',
#  'fun',
#  'phone',
#  'rushing',
#  'get',
#  'cause',
#  'want',
#  'use',
#  'learn',
#  'country',
#  'state',
#  'outside',
#  'well',
#  'computer',
#  'internet',
#  'new',
#  'way',
#  'learn',
#  'going',
#  'time',
#  'might',
#  'think',
#  'child',
#  'spends',
#  'lot',
#  'time',
#  'computer',
#  'ask',
#  'question',
#  'economy',
#  'sea',
#  'floor',
#  'spreading',
#  'even',
#  'date',
#  'surprise',
#  'much',
#  'know',
#  'believe',
#  'computer',
#  'much',
#  'interesting',
#  'class',
#  'day',
#  'reading',
#  'book',
#  'child',
#  'home',
#  'computer',
#  'local',
#  'library',
#  'better',
#  'friend',
#  'fresh',
#  'perpressured',
#  'something',
#  'know',
#  'isnt',
#  'right',
#  'might',
#  'know',
#  'child',
#  'cap',
#  'forbidde',
#  'hospital',
#  'bed',
#  'drive',
#  'rather',
#  'child',
#  'computer',
#  'learning',
#  'chatting',
#  'playing',
#  'game',
#  'safe',
#  'sound',
#  'home',
#  'community',
#  'place',
#  'hope',
#  'reached',
#  'point',
#  'understand',
#  'agree',
#  'computer',
#  'great',
#  'effect',
#  'child',
#  'give',
#  'u',
#  'time',
#  'chat',
#  'friend',
#  'new',
#  'people',
#  'help',
#  'u',
#  'learn',
#  'globe',
#  'believe',
#  'keep',
#  'u',
#  'troble',
#  'thank',
#  'listening']

# %%
# Training the word2vec model

# %%
from gensim.models import Word2Vec

# %%
num_features = 150

# %%
vec = Word2Vec(word, min_count=5, size=num_features)

# %%
vec.wv.vocab
# Out:
# {'dear': <gensim.models.keyedvectors.Vocab at 0x1bd02ab5688>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x1bd044d8948>,
#  'newspaper': <gensim.models.keyedvectors.Vocab at 0x1bd044d8788>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x1bd044aad48>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x1bd044b4a88>,
#  'computer': <gensim.models.keyedvectors.Vocab at 0x1bd044b4488>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x1bd044b4e48>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x1bd044b4c88>,
#  'learning': <gensim.models.keyedvectors.Vocab at 0x1bd044aae88>,
#  'skill': <gensim.models.keyedvectors.Vocab at 0x1bd044b43c8>,
#  'affect': <gensim.models.keyedvectors.Vocab at 0x1bd044b4648>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x1bd044b44c8>,
#  'u': <gensim.models.keyedvectors.Vocab at 0x1bd044b4048>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x1bd044b4fc8>,
#  'chat': <gensim.models.keyedvectors.Vocab at 0x1bd044b4708>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x1bd044ba608>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x1bd044ba0c8>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x1bd044ba148>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x1bd044ba748>,
#  'globe': <gensim.models.keyedvectors.Vocab at 0x1bd044ba6c8>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x1bd044ba4c8>,
#  'troble': <gensim.models.keyedvectors.Vocab at 0x1bd044ba248>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x1bd044ba808>,
#  'dont': <gensim.models.keyedvectors.Vocab at 0x1bd044babc8>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x1bd044ba1c8>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x1bd044bab48>,
#  'teenager': <gensim.models.keyedvectors.Vocab at 0x1bd044bac48>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x1bd044badc8>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x1bd044bac88>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x1bd044bae48>,
#  'buisness': <gensim.models.keyedvectors.Vocab at 0x1bd044bd508>,
#  'partner': <gensim.models.keyedvectors.Vocab at 0x1bd044bd408>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x1bd044bd5c8>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x1bd044bd308>,
#  'plenty': <gensim.models.keyedvectors.Vocab at 0x1bd044bd1c8>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x1bd044bd608>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x1bd044bd648>,
#  'organization': <gensim.models.keyedvectors.Vocab at 0x1bd044bd688>,
#  'cap': <gensim.models.keyedvectors.Vocab at 0x1bd044bd708>,
#  'facebook': <gensim.models.keyedvectors.Vocab at 0x1bd044bd948>,
#  'myspace': <gensim.models.keyedvectors.Vocab at 0x1bd044bdb08>,
#  'ect': <gensim.models.keyedvectors.Vocab at 0x1bd044bdbc8>,
#  'setting': <gensim.models.keyedvectors.Vocab at 0x1bd044bdd08>,
#  'meeting': <gensim.models.keyedvectors.Vocab at 0x1bd044bde48>,
#  'bos': <gensim.models.keyedvectors.Vocab at 0x1bd044bd588>,
#  'fun': <gensim.models.keyedvectors.Vocab at 0x1bd044bdf88>,
#  'rushing': <gensim.models.keyedvectors.Vocab at 0x1bd044c1908>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x1bd044c1248>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x1bd044c1108>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x1bd044c1188>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x1bd044c11c8>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x1bd044c13c8>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x1bd044c1088>,
#  'outside': <gensim.models.keyedvectors.Vocab at 0x1bd044c14c8>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x1bd044c1588>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x1bd044c1c88>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x1bd044c1308>,
#  'spends': <gensim.models.keyedvectors.Vocab at 0x1bd044c1788>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x1bd044c1648>,
#  'ask': <gensim.models.keyedvectors.Vocab at 0x1bd044c1a08>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x1bd044c1bc8>,
#  'economy': <gensim.models.keyedvectors.Vocab at 0x1bd044c1e88>,
#  'sea': <gensim.models.keyedvectors.Vocab at 0x1bd044c1dc8>,
#  'floor': <gensim.models.keyedvectors.Vocab at 0x1bd044c1988>,
#  'spreading': <gensim.models.keyedvectors.Vocab at 0x1bd044c6588>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x1bd044c67c8>,
#  'date': <gensim.models.keyedvectors.Vocab at 0x1bd044c6408>,
#  'surprise': <gensim.models.keyedvectors.Vocab at 0x1bd044c63c8>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x1bd044c6888>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x1bd044c6b48>,
#  'believe': <gensim.models.keyedvectors.Vocab at 0x1bd044c6a08>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x1bd044c6048>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x1bd044c6d08>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x1bd044c68c8>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x1bd044c6808>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x1bd044c6f88>,
#  'home': <gensim.models.keyedvectors.Vocab at 0x1bd044c6688>,
#  'library': <gensim.models.keyedvectors.Vocab at 0x1bd044c91c8>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x1bd044c9388>,
#  'fresh': <gensim.models.keyedvectors.Vocab at 0x1bd044c9608>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x1bd044c9308>,
#  'isnt': <gensim.models.keyedvectors.Vocab at 0x1bd044c97c8>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x1bd044c9208>,
#  'hospital': <gensim.models.keyedvectors.Vocab at 0x1bd044c9a08>,
#  'bed': <gensim.models.keyedvectors.Vocab at 0x1bd044c9bc8>,
#  'drive': <gensim.models.keyedvectors.Vocab at 0x1bd044c90c8>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x1bd044c9688>,
#  'chatting': <gensim.models.keyedvectors.Vocab at 0x1bd044c99c8>,
#  'playing': <gensim.models.keyedvectors.Vocab at 0x1bd044c9548>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x1bd044c9b08>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x1bd044c9d08>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x1bd044c9408>,
#  'community': <gensim.models.keyedvectors.Vocab at 0x1bd044c9c48>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x1bd044cc348>,
#  'hope': <gensim.models.keyedvectors.Vocab at 0x1bd044cc608>,
#  'reached': <gensim.models.keyedvectors.Vocab at 0x1bd044cc788>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x1bd044cc848>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x1bd044cc208>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x1bd044cc4c8>,
#  'thank': <gensim.models.keyedvectors.Vocab at 0x1bd044cc6c8>,
#  'listening': <gensim.models.keyedvectors.Vocab at 0x1bd044cc088>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x1bd044cce88>,
#  'benefit': <gensim.models.keyedvectors.Vocab at 0x1bd044cc2c8>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x1bd044cc888>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x1bd044cc8c8>,
#  'talking': <gensim.models.keyedvectors.Vocab at 0x1bd044cc808>,
#  'becoming': <gensim.models.keyedvectors.Vocab at 0x1bd044ccfc8>,
#  'others': <gensim.models.keyedvectors.Vocab at 0x1bd044cc908>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x1bd044d0448>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x1bd044d0248>,
#  'location': <gensim.models.keyedvectors.Vocab at 0x1bd044d0648>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x1bd044d0488>,
#  'ourselfs': <gensim.models.keyedvectors.Vocab at 0x1bd044d0408>,
#  'million': <gensim.models.keyedvectors.Vocab at 0x1bd044d0188>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x1bd044d0848>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x1bd044d0d08>,
#  'helping': <gensim.models.keyedvectors.Vocab at 0x1bd044d0f88>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x1bd044d0348>,
#  'planning': <gensim.models.keyedvectors.Vocab at 0x1bd044d0a88>,
#  'house': <gensim.models.keyedvectors.Vocab at 0x1bd044d05c8>,
#  'plan': <gensim.models.keyedvectors.Vocab at 0x1bd044d0c48>,
#  'typing': <gensim.models.keyedvectors.Vocab at 0x1bd044d0dc8>,
#  'num': <gensim.models.keyedvectors.Vocab at 0x1bd044d0fc8>,
#  'page': <gensim.models.keyedvectors.Vocab at 0x1bd044d0688>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x1bd044d5e08>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x1bd044d5a88>,
#  'le': <gensim.models.keyedvectors.Vocab at 0x1bd044d5ac8>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x1bd044d5bc8>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x1bd044d5d08>,
#  'go': <gensim.models.keyedvectors.Vocab at 0x1bd044d5dc8>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x1bd044d5c88>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x1bd044d5308>,
#  'technology': <gensim.models.keyedvectors.Vocab at 0x1bd044d5788>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x1bd044d5408>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x1bd044d5648>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x1bd044d5848>,
#  'facebooks': <gensim.models.keyedvectors.Vocab at 0x1bd044d58c8>,
#  'aim': <gensim.models.keyedvectors.Vocab at 0x1bd044d5908>,
#  'conversation': <gensim.models.keyedvectors.Vocab at 0x1bd044d5288>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x1bd044d5948>,
#  'bad': <gensim.models.keyedvectors.Vocab at 0x1bd044d5888>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x1bd044dbd88>,
#  'never': <gensim.models.keyedvectors.Vocab at 0x1bd044db4c8>,
#  'talk': <gensim.models.keyedvectors.Vocab at 0x1bd044db5c8>,
#  'fortunate': <gensim.models.keyedvectors.Vocab at 0x1bd044dba08>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x1bd044db088>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x1bd044db288>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x1bd044dbe88>,
#  'finding': <gensim.models.keyedvectors.Vocab at 0x1bd044dbc48>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x1bd044dbf48>,
#  'onto': <gensim.models.keyedvectors.Vocab at 0x1bd044dbb08>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x1bd044db0c8>,
#  'coordinate': <gensim.models.keyedvectors.Vocab at 0x1bd044db308>,
#  'supposed': <gensim.models.keyedvectors.Vocab at 0x1bd044db708>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x1bd044db3c8>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x1bd044dbdc8>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x1bd044e0448>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x1bd044e0408>,
#  'draw': <gensim.models.keyedvectors.Vocab at 0x1bd044e02c8>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x1bd044e0988>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x1bd044e0888>,
#  'hand': <gensim.models.keyedvectors.Vocab at 0x1bd044e0f88>,
#  'ugly': <gensim.models.keyedvectors.Vocab at 0x1bd044e0388>,
#  'mark': <gensim.models.keyedvectors.Vocab at 0x1bd044e0348>,
#  'drawing': <gensim.models.keyedvectors.Vocab at 0x1bd044e0108>,
#  'worker': <gensim.models.keyedvectors.Vocab at 0x1bd044e08c8>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x1bd044e0a48>,
#  'write': <gensim.models.keyedvectors.Vocab at 0x1bd044e0a08>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x1bd044e0e48>,
#  'paper': <gensim.models.keyedvectors.Vocab at 0x1bd044e3208>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x1bd044e3388>,
#  'essay': <gensim.models.keyedvectors.Vocab at 0x1bd044e3448>,
#  'fit': <gensim.models.keyedvectors.Vocab at 0x1bd044e34c8>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x1bd044e35c8>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x1bd044e3288>,
#  'hav': <gensim.models.keyedvectors.Vocab at 0x1bd044e31c8>,
#  'needed': <gensim.models.keyedvectors.Vocab at 0x1bd044e3a08>,
#  'adays': <gensim.models.keyedvectors.Vocab at 0x1bd044e3648>,
#  'impacted': <gensim.models.keyedvectors.Vocab at 0x1bd044e3108>,
#  'machine': <gensim.models.keyedvectors.Vocab at 0x1bd044e3088>,
#  'showed': <gensim.models.keyedvectors.Vocab at 0x1bd044e33c8>,
#  'mom': <gensim.models.keyedvectors.Vocab at 0x1bd044e3688>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x1bd044e3a88>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x1bd044e3588>,
#  'invention': <gensim.models.keyedvectors.Vocab at 0x1bd044e3dc8>,
#  'sense': <gensim.models.keyedvectors.Vocab at 0x1bd044e3f48>,
#  'bread': <gensim.models.keyedvectors.Vocab at 0x1bd044e9cc8>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x1bd044e95c8>,
#  'click': <gensim.models.keyedvectors.Vocab at 0x1bd044e94c8>,
#  'button': <gensim.models.keyedvectors.Vocab at 0x1bd044e9b48>,
#  'self': <gensim.models.keyedvectors.Vocab at 0x1bd044e9748>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x1bd044e9e08>,
#  'neat': <gensim.models.keyedvectors.Vocab at 0x1bd044e9f48>,
#  'prepared': <gensim.models.keyedvectors.Vocab at 0x1bd044e99c8>,
#  'printed': <gensim.models.keyedvectors.Vocab at 0x1bd044e9a08>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x1bd044e9048>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x1bd044e9b88>,
#  'agrees': <gensim.models.keyedvectors.Vocab at 0x1bd044e90c8>,
#  'society': <gensim.models.keyedvectors.Vocab at 0x1bd044e9208>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x1bd044e9488>,
#  'advance': <gensim.models.keyedvectors.Vocab at 0x1bd044e9588>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x1bd044e9ac8>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x1bd044e9ec8>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x1bd044ecd88>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x1bd044ec648>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x1bd044ecfc8>,
#  'man': <gensim.models.keyedvectors.Vocab at 0x1bd044ec448>,
#  'accomplishment': <gensim.models.keyedvectors.Vocab at 0x1bd044ec688>,
#  'helpful': <gensim.models.keyedvectors.Vocab at 0x1bd044ec0c8>,
#  'news': <gensim.models.keyedvectors.Vocab at 0x1bd044ec148>,
#  'live': <gensim.models.keyedvectors.Vocab at 0x1bd044ec048>,
#  'stream': <gensim.models.keyedvectors.Vocab at 0x1bd044ec288>,
#  'wrong': <gensim.models.keyedvectors.Vocab at 0x1bd044ec4c8>,
#  'spend': <gensim.models.keyedvectors.Vocab at 0x1bd044ec788>,
#  'interacting': <gensim.models.keyedvectors.Vocab at 0x1bd044ec608>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x1bd044ec588>,
#  'grow': <gensim.models.keyedvectors.Vocab at 0x1bd044ecac8>,
#  'author': <gensim.models.keyedvectors.Vocab at 0x1bd044ecbc8>,
#  'journalist': <gensim.models.keyedvectors.Vocab at 0x1bd044f0108>,
#  'fact': <gensim.models.keyedvectors.Vocab at 0x1bd044f0508>,
#  'involve': <gensim.models.keyedvectors.Vocab at 0x1bd044f06c8>,
#  'exactly': <gensim.models.keyedvectors.Vocab at 0x1bd044f0708>,
#  'expert': <gensim.models.keyedvectors.Vocab at 0x1bd044f0808>,
#  'spending': <gensim.models.keyedvectors.Vocab at 0x1bd044f0148>,
#  'exercising': <gensim.models.keyedvectors.Vocab at 0x1bd044f05c8>,
#  'enjoying': <gensim.models.keyedvectors.Vocab at 0x1bd044f0f48>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x1bd044f0848>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x1bd044f01c8>,
#  'living': <gensim.models.keyedvectors.Vocab at 0x1bd044f0288>,
#  'choose': <gensim.models.keyedvectors.Vocab at 0x1bd044f08c8>,
#  'honest': <gensim.models.keyedvectors.Vocab at 0x1bd044f0348>,
#  'concern': <gensim.models.keyedvectors.Vocab at 0x1bd044f0988>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x1bd044f0a88>,
#  'interact': <gensim.models.keyedvectors.Vocab at 0x1bd044f0b88>,
#  'thousand': <gensim.models.keyedvectors.Vocab at 0x1bd044f0f88>,
#  'kid': <gensim.models.keyedvectors.Vocab at 0x1bd044f0c08>,
#  'street': <gensim.models.keyedvectors.Vocab at 0x1bd044f0d48>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x1bd044f0c88>,
#  'causing': <gensim.models.keyedvectors.Vocab at 0x1bd044f0788>,
#  'trouble': <gensim.models.keyedvectors.Vocab at 0x1bd044f0408>,
#  'locate': <gensim.models.keyedvectors.Vocab at 0x1bd044f3588>,
#  'wanted': <gensim.models.keyedvectors.Vocab at 0x1bd044f34c8>,
#  'criminal': <gensim.models.keyedvectors.Vocab at 0x1bd044f3648>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x1bd044f3248>,
#  'useful': <gensim.models.keyedvectors.Vocab at 0x1bd044f3388>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x1bd044f3c88>,
#  'benifit': <gensim.models.keyedvectors.Vocab at 0x1bd044f3e08>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x1bd044f3788>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x1bd044f37c8>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x1bd044f3d08>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x1bd044f3f48>,
#  'beat': <gensim.models.keyedvectors.Vocab at 0x1bd044f3108>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x1bd044f3888>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x1bd044f6248>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x1bd044f63c8>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x1bd044f6c08>,
#  'webcam': <gensim.models.keyedvectors.Vocab at 0x1bd044f6788>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x1bd044f6648>,
#  'mail': <gensim.models.keyedvectors.Vocab at 0x1bd044f6e88>,
#  'percent': <gensim.models.keyedvectors.Vocab at 0x1bd044f68c8>,
#  'student': <gensim.models.keyedvectors.Vocab at 0x1bd044f6a88>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x1bd044f6508>,
#  'grade': <gensim.models.keyedvectors.Vocab at 0x1bd044f6848>,
#  'refer': <gensim.models.keyedvectors.Vocab at 0x1bd044f6f88>,
#  'reliable': <gensim.models.keyedvectors.Vocab at 0x1bd044f6988>,
#  'reasearch': <gensim.models.keyedvectors.Vocab at 0x1bd044f6fc8>,
#  'store': <gensim.models.keyedvectors.Vocab at 0x1bd044f6e48>,
#  'worldwide': <gensim.models.keyedvectors.Vocab at 0x1bd044f6a08>,
#  'allowed': <gensim.models.keyedvectors.Vocab at 0x1bd044f6f48>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x1bd044fbbc8>,
#  'exist': <gensim.models.keyedvectors.Vocab at 0x1bd044fb948>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x1bd044fb0c8>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x1bd044fb788>,
#  'communication': <gensim.models.keyedvectors.Vocab at 0x1bd044fb648>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x1bd044fb5c8>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x1bd044fb2c8>,
#  'cheaper': <gensim.models.keyedvectors.Vocab at 0x1bd044fb988>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x1bd044fb888>,
#  'event': <gensim.models.keyedvectors.Vocab at 0x1bd044fbc88>,
#  'planed': <gensim.models.keyedvectors.Vocab at 0x1bd044fb708>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x1bd044fb048>,
#  'homework': <gensim.models.keyedvectors.Vocab at 0x1bd044fbf08>,
#  'sick': <gensim.models.keyedvectors.Vocab at 0x1bd044fb808>,
#  'studying': <gensim.models.keyedvectors.Vocab at 0x1bd044fb7c8>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x1bd044fb848>,
#  'contact': <gensim.models.keyedvectors.Vocab at 0x1bd044fbd08>,
#  'teacher': <gensim.models.keyedvectors.Vocab at 0x1bd044fb148>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x1bd044ff348>,
#  'office': <gensim.models.keyedvectors.Vocab at 0x1bd044ffd48>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x1bd044ff608>,
#  'letter': <gensim.models.keyedvectors.Vocab at 0x1bd044ff708>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x1bd044fff48>,
#  'president': <gensim.models.keyedvectors.Vocab at 0x1bd044ff408>,
#  'imposible': <gensim.models.keyedvectors.Vocab at 0x1bd044ff5c8>,
#  'telling': <gensim.models.keyedvectors.Vocab at 0x1bd044ff9c8>,
#  'zip': <gensim.models.keyedvectors.Vocab at 0x1bd044ffb88>,
#  'code': <gensim.models.keyedvectors.Vocab at 0x1bd044ff488>,
#  'heavy': <gensim.models.keyedvectors.Vocab at 0x1bd044ffc88>,
#  'happening': <gensim.models.keyedvectors.Vocab at 0x1bd044ffec8>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x1bd044ff988>,
#  'quick': <gensim.models.keyedvectors.Vocab at 0x1bd044ffb48>,
#  'took': <gensim.models.keyedvectors.Vocab at 0x1bd044ffe88>,
#  'pole': <gensim.models.keyedvectors.Vocab at 0x1bd04502908>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x1bd04502688>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x1bd04502808>,
#  'currently': <gensim.models.keyedvectors.Vocab at 0x1bd04502888>,
#  'survey': <gensim.models.keyedvectors.Vocab at 0x1bd045027c8>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x1bd045029c8>,
#  'fore': <gensim.models.keyedvectors.Vocab at 0x1bd04502408>,
#  'reason': <gensim.models.keyedvectors.Vocab at 0x1bd04502ac8>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x1bd04502a08>,
#  'document': <gensim.models.keyedvectors.Vocab at 0x1bd04502c48>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x1bd04502d08>,
#  'gotten': <gensim.models.keyedvectors.Vocab at 0x1bd04502f88>,
#  'assignment': <gensim.models.keyedvectors.Vocab at 0x1bd04502e48>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x1bd04505908>,
#  'reporter': <gensim.models.keyedvectors.Vocab at 0x1bd04505e08>,
#  'article': <gensim.models.keyedvectors.Vocab at 0x1bd04505488>,
#  'occur': <gensim.models.keyedvectors.Vocab at 0x1bd04505108>,
#  'buissness': <gensim.models.keyedvectors.Vocab at 0x1bd04505248>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x1bd04505308>,
#  'advertise': <gensim.models.keyedvectors.Vocab at 0x1bd04505688>,
#  'shop': <gensim.models.keyedvectors.Vocab at 0x1bd045058c8>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x1bd045053c8>,
#  'reported': <gensim.models.keyedvectors.Vocab at 0x1bd04505b88>,
#  'position': <gensim.models.keyedvectors.Vocab at 0x1bd045054c8>,
#  'import': <gensim.models.keyedvectors.Vocab at 0x1bd04505d88>,
#  'promote': <gensim.models.keyedvectors.Vocab at 0x1bd04505388>,
#  'save': <gensim.models.keyedvectors.Vocab at 0x1bd04505448>,
#  'tree': <gensim.models.keyedvectors.Vocab at 0x1bd04505548>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x1bd04505f08>,
#  'explain': <gensim.models.keyedvectors.Vocab at 0x1bd04505a08>,
#  'star': <gensim.models.keyedvectors.Vocab at 0x1bd04505e48>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x1bd04482f08>,
#  'owner': <gensim.models.keyedvectors.Vocab at 0x1bd04589508>,
#  'saved': <gensim.models.keyedvectors.Vocab at 0x1bd044b1288>,
#  'resturant': <gensim.models.keyedvectors.Vocab at 0x1bd044b1d88>,
#  'wer': <gensim.models.keyedvectors.Vocab at 0x1bd044b1e08>,
#  'conclusion': <gensim.models.keyedvectors.Vocab at 0x1bd044b1d08>,
#  'everyday': <gensim.models.keyedvectors.Vocab at 0x1bd044b13c8>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x1bd04505cc8>,
#  'communicate': <gensim.models.keyedvectors.Vocab at 0x1bd0450a348>,
#  'reaserch': <gensim.models.keyedvectors.Vocab at 0x1bd0450ac48>,
#  'subject': <gensim.models.keyedvectors.Vocab at 0x1bd0450a988>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x1bd0450a648>,
#  'moderation': <gensim.models.keyedvectors.Vocab at 0x1bd0450afc8>,
#  'tool': <gensim.models.keyedvectors.Vocab at 0x1bd0450aec8>,
#  'connect': <gensim.models.keyedvectors.Vocab at 0x1bd0450a188>,
#  'contain': <gensim.models.keyedvectors.Vocab at 0x1bd0450a7c8>,
#  'education': <gensim.models.keyedvectors.Vocab at 0x1bd0450a148>,
#  'computors': <gensim.models.keyedvectors.Vocab at 0x1bd0450a548>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x1bd0450adc8>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x1bd0450aac8>,
#  'advantage': <gensim.models.keyedvectors.Vocab at 0x1bd0450ae48>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x1bd0450ad48>,
#  'member': <gensim.models.keyedvectors.Vocab at 0x1bd0450af08>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x1bd0450eac8>,
#  'car': <gensim.models.keyedvectors.Vocab at 0x1bd0450e048>,
#  'includes': <gensim.models.keyedvectors.Vocab at 0x1bd0450e708>,
#  'sitting': <gensim.models.keyedvectors.Vocab at 0x1bd0450ea88>,
#  'calling': <gensim.models.keyedvectors.Vocab at 0x1bd0450eb48>,
#  'everywhere': <gensim.models.keyedvectors.Vocab at 0x1bd0450e0c8>,
#  'board': <gensim.models.keyedvectors.Vocab at 0x1bd0450e3c8>,
#  'easier': <gensim.models.keyedvectors.Vocab at 0x1bd0450ed88>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x1bd0450e908>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x1bd0450efc8>,
#  'kind': <gensim.models.keyedvectors.Vocab at 0x1bd0450ee48>,
#  'activity': <gensim.models.keyedvectors.Vocab at 0x1bd0450ec88>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x1bd0450ef08>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x1bd0450eec8>,
#  'bringing': <gensim.models.keyedvectors.Vocab at 0x1bd0450ef88>,
#  'tip': <gensim.models.keyedvectors.Vocab at 0x1bd04511b08>,
#  'finger': <gensim.models.keyedvectors.Vocab at 0x1bd04511ac8>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x1bd04511948>,
#  'secondly': <gensim.models.keyedvectors.Vocab at 0x1bd045119c8>,
#  'collage': <gensim.models.keyedvectors.Vocab at 0x1bd04511508>,
#  'arn': <gensim.models.keyedvectors.Vocab at 0x1bd04511888>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x1bd04511308>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x1bd04511c88>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x1bd045115c8>,
#  'missed': <gensim.models.keyedvectors.Vocab at 0x1bd04511b48>,
#  'lastly': <gensim.models.keyedvectors.Vocab at 0x1bd04511cc8>,
#  'classroom': <gensim.models.keyedvectors.Vocab at 0x1bd04511b88>,
#  'afford': <gensim.models.keyedvectors.Vocab at 0x1bd04516648>,
#  'hard': <gensim.models.keyedvectors.Vocab at 0x1bd04516a88>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x1bd04516608>,
#  'lean': <gensim.models.keyedvectors.Vocab at 0x1bd04516fc8>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x1bd04516788>,
#  'result': <gensim.models.keyedvectors.Vocab at 0x1bd04516b48>,
#  'improve': <gensim.models.keyedvectors.Vocab at 0x1bd04516c48>,
#  'crazy': <gensim.models.keyedvectors.Vocab at 0x1bd0451a708>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x1bd0451ab08>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x1bd0451a888>,
#  'lighter': <gensim.models.keyedvectors.Vocab at 0x1bd0451a208>,
#  'nation': <gensim.models.keyedvectors.Vocab at 0x1bd0451a548>,
#  'flight': <gensim.models.keyedvectors.Vocab at 0x1bd0451a9c8>,
#  'vacation': <gensim.models.keyedvectors.Vocab at 0x1bd0451ab48>,
#  'rental': <gensim.models.keyedvectors.Vocab at 0x1bd0451acc8>,
#  'nice': <gensim.models.keyedvectors.Vocab at 0x1bd0451d388>,
#  'negative': <gensim.models.keyedvectors.Vocab at 0x1bd0451d648>,
#  'ace': <gensim.models.keyedvectors.Vocab at 0x1bd0451dc08>,
#  'daily': <gensim.models.keyedvectors.Vocab at 0x1bd0451d588>,
#  'america': <gensim.models.keyedvectors.Vocab at 0x1bd0451dac8>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x1bd0451df48>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x1bd0451dc88>,
#  'cant': <gensim.models.keyedvectors.Vocab at 0x1bd04522408>,
#  'exercise': <gensim.models.keyedvectors.Vocab at 0x1bd04522048>,
#  'wasting': <gensim.models.keyedvectors.Vocab at 0x1bd04522448>,
#  'physical': <gensim.models.keyedvectors.Vocab at 0x1bd04522608>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x1bd04522108>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x1bd04522848>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x1bd04522208>,
#  'sit': <gensim.models.keyedvectors.Vocab at 0x1bd04522908>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x1bd04522e08>,
#  'walk': <gensim.models.keyedvectors.Vocab at 0x1bd04522a88>,
#  'email': <gensim.models.keyedvectors.Vocab at 0x1bd04525208>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x1bd04525308>,
#  'difference': <gensim.models.keyedvectors.Vocab at 0x1bd04525388>,
#  'er': <gensim.models.keyedvectors.Vocab at 0x1bd045256c8>,
#  'literally': <gensim.models.keyedvectors.Vocab at 0x1bd04525908>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x1bd04525e48>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x1bd04525d48>,
#  'everthing': <gensim.models.keyedvectors.Vocab at 0x1bd04525f08>,
#  'gone': <gensim.models.keyedvectors.Vocab at 0x1bd04581308>,
#  'hurt': <gensim.models.keyedvectors.Vocab at 0x1bd04581e88>,
#  'happened': <gensim.models.keyedvectors.Vocab at 0x1bd04581ec8>,
#  'grandpa': <gensim.models.keyedvectors.Vocab at 0x1bd04581a48>,
#  'wood': <gensim.models.keyedvectors.Vocab at 0x1bd04581f88>,
#  'chair': <gensim.models.keyedvectors.Vocab at 0x1bd0374d448>,
#  'muscle': <gensim.models.keyedvectors.Vocab at 0x1bd045db388>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x1bd045dbf48>,
#  'depending': <gensim.models.keyedvectors.Vocab at 0x1bd04529ec8>,
#  'safety': <gensim.models.keyedvectors.Vocab at 0x1bd04529a88>,
#  'natural': <gensim.models.keyedvectors.Vocab at 0x1bd045292c8>,
#  'opinion': <gensim.models.keyedvectors.Vocab at 0x1bd04529208>,
#  'increasing': <gensim.models.keyedvectors.Vocab at 0x1bd04529408>,
#  'benefiting': <gensim.models.keyedvectors.Vocab at 0x1bd04529648>,
#  'initially': <gensim.models.keyedvectors.Vocab at 0x1bd04529888>,
#  'risk': <gensim.models.keyedvectors.Vocab at 0x1bd0452d108>,
#  'begin': <gensim.models.keyedvectors.Vocab at 0x1bd0452d1c8>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x1bd0452d888>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x1bd0452dd08>,
#  'began': <gensim.models.keyedvectors.Vocab at 0x1bd0452db88>,
#  'predator': <gensim.models.keyedvectors.Vocab at 0x1bd0452dc48>,
#  'unless': <gensim.models.keyedvectors.Vocab at 0x1bd0452dbc8>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x1bd044ae488>,
#  'somewhere': <gensim.models.keyedvectors.Vocab at 0x1bd044ae908>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x1bd044ae9c8>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x1bd044ae948>,
#  'moreover': <gensim.models.keyedvectors.Vocab at 0x1bd044ae388>,
#  'study': <gensim.models.keyedvectors.Vocab at 0x1bd044aeac8>,
#  'widely': <gensim.models.keyedvectors.Vocab at 0x1bd044aeb48>,
#  'exposed': <gensim.models.keyedvectors.Vocab at 0x1bd044ae3c8>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x1bd044aee88>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x1bd044ae848>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x1bd044ae788>,
#  'finally': <gensim.models.keyedvectors.Vocab at 0x1bd044aed48>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x1bd044ae688>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x1bd044ae148>,
#  'furthermore': <gensim.models.keyedvectors.Vocab at 0x1bd044ae048>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x1bd044aebc8>,
#  'immense': <gensim.models.keyedvectors.Vocab at 0x1bd044ae288>,
#  'landscape': <gensim.models.keyedvectors.Vocab at 0x1bd04531f08>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x1bd045313c8>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x1bd04531288>,
#  'dense': <gensim.models.keyedvectors.Vocab at 0x1bd04531748>,
#  'forest': <gensim.models.keyedvectors.Vocab at 0x1bd04531488>,
#  'lush': <gensim.models.keyedvectors.Vocab at 0x1bd04531a08>,
#  'valley': <gensim.models.keyedvectors.Vocab at 0x1bd04531c88>,
#  'depend': <gensim.models.keyedvectors.Vocab at 0x1bd04531908>,
#  'teach': <gensim.models.keyedvectors.Vocab at 0x1bd045319c8>,
#  'cease': <gensim.models.keyedvectors.Vocab at 0x1bd04531d88>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x1bd04531fc8>,
#  'experiencing': <gensim.models.keyedvectors.Vocab at 0x1bd04535948>,
#  'smell': <gensim.models.keyedvectors.Vocab at 0x1bd045350c8>,
#  'taste': <gensim.models.keyedvectors.Vocab at 0x1bd04535748>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x1bd04535508>,
#  'went': <gensim.models.keyedvectors.Vocab at 0x1bd04535dc8>,
#  'grand': <gensim.models.keyedvectors.Vocab at 0x1bd04535808>,
#  'canyon': <gensim.models.keyedvectors.Vocab at 0x1bd04535a08>,
#  'learned': <gensim.models.keyedvectors.Vocab at 0x1bd045356c8>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x1bd045351c8>,
#  'thirdly': <gensim.models.keyedvectors.Vocab at 0x1bd04535988>,
#  'ruined': <gensim.models.keyedvectors.Vocab at 0x1bd04535a88>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x1bd04535c08>,
#  'embarrasing': <gensim.models.keyedvectors.Vocab at 0x1bd04538108>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x1bd045382c8>,
#  'forever': <gensim.models.keyedvectors.Vocab at 0x1bd04538308>,
#  'thus': <gensim.models.keyedvectors.Vocab at 0x1bd045383c8>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x1bd04538148>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x1bd04538088>,
#  'addict': <gensim.models.keyedvectors.Vocab at 0x1bd04538508>,
#  'ruin': <gensim.models.keyedvectors.Vocab at 0x1bd04538248>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x1bd04538448>,
#  'fault': <gensim.models.keyedvectors.Vocab at 0x1bd045387c8>,
#  'enjoy': <gensim.models.keyedvectors.Vocab at 0x1bd04538cc8>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x1bd04538848>,
#  'ignore': <gensim.models.keyedvectors.Vocab at 0x1bd045389c8>,
#  'numerous': <gensim.models.keyedvectors.Vocab at 0x1bd04538e08>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x1bd04538ec8>,
#  'encourage': <gensim.models.keyedvectors.Vocab at 0x1bd04538c88>,
#  'decrease': <gensim.models.keyedvectors.Vocab at 0x1bd04538b08>,
#  'complicated': <gensim.models.keyedvectors.Vocab at 0x1bd04538fc8>,
#  'eye': <gensim.models.keyedvectors.Vocab at 0x1bd0453d2c8>,
#  'coordination': <gensim.models.keyedvectors.Vocab at 0x1bd0453d348>,
#  'faraway': <gensim.models.keyedvectors.Vocab at 0x1bd0453d448>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x1bd0453d808>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x1bd0453d1c8>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x1bd0453d9c8>,
#  'screen': <gensim.models.keyedvectors.Vocab at 0x1bd0453dc88>,
#  'moving': <gensim.models.keyedvectors.Vocab at 0x1bd0453d248>,
#  'mouse': <gensim.models.keyedvectors.Vocab at 0x1bd0453de88>,
#  'mostly': <gensim.models.keyedvectors.Vocab at 0x1bd0453d308>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x1bd0453d3c8>,
#  'sport': <gensim.models.keyedvectors.Vocab at 0x1bd0453d8c8>,
#  'baseball': <gensim.models.keyedvectors.Vocab at 0x1bd0453d608>,
#  'element': <gensim.models.keyedvectors.Vocab at 0x1bd0453db48>,
#  'stronger': <gensim.models.keyedvectors.Vocab at 0x1bd035e5e48>,
#  'feild': <gensim.models.keyedvectors.Vocab at 0x1bd035e5c48>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x1bd035e5fc8>,
#  'note': <gensim.models.keyedvectors.Vocab at 0x1bd035e5448>,
#  'involved': <gensim.models.keyedvectors.Vocab at 0x1bd035e5108>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x1bd035e55c8>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x1bd035e50c8>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x1bd035e5848>,
#  'properly': <gensim.models.keyedvectors.Vocab at 0x1bd035e5f88>,
#  'doctor': <gensim.models.keyedvectors.Vocab at 0x1bd046536c8>,
#  'healthy': <gensim.models.keyedvectors.Vocab at 0x1bd04653448>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x1bd04653748>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x1bd046535c8>,
#  'updated': <gensim.models.keyedvectors.Vocab at 0x1bd04653808>,
#  'culture': <gensim.models.keyedvectors.Vocab at 0x1bd04653648>,
#  'tradition': <gensim.models.keyedvectors.Vocab at 0x1bd04653688>,
#  'ignorant': <gensim.models.keyedvectors.Vocab at 0x1bd04653588>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x1bd046538c8>,
#  'broke': <gensim.models.keyedvectors.Vocab at 0x1bd04653508>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x1bd04653888>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x1bd04653948>,
#  'answering': <gensim.models.keyedvectors.Vocab at 0x1bd04653c48>,
#  'happens': <gensim.models.keyedvectors.Vocab at 0x1bd046539c8>,
#  'employee': <gensim.models.keyedvectors.Vocab at 0x1bd04653d08>,
#  'co': <gensim.models.keyedvectors.Vocab at 0x1bd04653a48>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x1bd04653d88>,
#  'desk': <gensim.models.keyedvectors.Vocab at 0x1bd04653a88>,
#  'faster': <gensim.models.keyedvectors.Vocab at 0x1bd04653e48>,
#  'opposed': <gensim.models.keyedvectors.Vocab at 0x1bd04653988>,
#  'critical': <gensim.models.keyedvectors.Vocab at 0x1bd04653f88>,
#  'reader': <gensim.models.keyedvectors.Vocab at 0x1bd04653ac8>,
#  'dramatic': <gensim.models.keyedvectors.Vocab at 0x1bd04653a08>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x1bd04653c88>,
#  'changed': <gensim.models.keyedvectors.Vocab at 0x1bd04653f08>,
#  'device': <gensim.models.keyedvectors.Vocab at 0x1bd04653d48>,
#  'provides': <gensim.models.keyedvectors.Vocab at 0x1bd04653dc8>,
#  'entertainment': <gensim.models.keyedvectors.Vocab at 0x1bd04296108>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x1bd04296148>,
#  'everyones': <gensim.models.keyedvectors.Vocab at 0x1bd04296088>,
#  'imagine': <gensim.models.keyedvectors.Vocab at 0x1bd042963c8>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x1bd04296288>,
#  'notice': <gensim.models.keyedvectors.Vocab at 0x1bd042964c8>,
#  'empty': <gensim.models.keyedvectors.Vocab at 0x1bd04296548>,
#  'grocery': <gensim.models.keyedvectors.Vocab at 0x1bd04296308>,
#  'shopping': <gensim.models.keyedvectors.Vocab at 0x1bd04296608>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x1bd04296248>,
#  'ther': <gensim.models.keyedvectors.Vocab at 0x1bd04296448>,
#  'deal': <gensim.models.keyedvectors.Vocab at 0x1bd04296508>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x1bd04296388>,
#  'deliver': <gensim.models.keyedvectors.Vocab at 0x1bd04296808>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x1bd042968c8>,
#  'amazing': <gensim.models.keyedvectors.Vocab at 0x1bd04296688>,
#  'leaving': <gensim.models.keyedvectors.Vocab at 0x1bd04296b08>,
#  'purchase': <gensim.models.keyedvectors.Vocab at 0x1bd042965c8>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x1bd04296708>,
#  'sold': <gensim.models.keyedvectors.Vocab at 0x1bd04296648>,
#  'toy': <gensim.models.keyedvectors.Vocab at 0x1bd04296cc8>,
#  'hat': <gensim.models.keyedvectors.Vocab at 0x1bd042961c8>,
#  'curtain': <gensim.models.keyedvectors.Vocab at 0x1bd04296e08>,
#  'room': <gensim.models.keyedvectors.Vocab at 0x1bd04296848>,
#  'item': <gensim.models.keyedvectors.Vocab at 0x1bd04296ec8>,
#  'relative': <gensim.models.keyedvectors.Vocab at 0x1bd04296c08>,
#  'dosen': <gensim.models.keyedvectors.Vocab at 0x1bd04296c48>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x1bd04296d88>,
#  'anyone': <gensim.models.keyedvectors.Vocab at 0x1bd04296ac8>,
#  'adress': <gensim.models.keyedvectors.Vocab at 0x1bd04296e88>,
#  'ease': <gensim.models.keyedvectors.Vocab at 0x1bd04296f48>,
#  'boom': <gensim.models.keyedvectors.Vocab at 0x1bd04296f08>,
#  'instant': <gensim.models.keyedvectors.Vocab at 0x1bd04296b88>,
#  'face': <gensim.models.keyedvectors.Vocab at 0x1bd04296f88>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x1bd0429b0c8>,
#  'watching': <gensim.models.keyedvectors.Vocab at 0x1bd0429b1c8>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x1bd0429b248>,
#  'comfort': <gensim.models.keyedvectors.Vocab at 0x1bd0429b2c8>,
#  'listing': <gensim.models.keyedvectors.Vocab at 0x1bd0429b348>,
#  'music': <gensim.models.keyedvectors.Vocab at 0x1bd0429b388>,
#  'probable': <gensim.models.keyedvectors.Vocab at 0x1bd0429b408>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x1bd0429b588>,
#  'selection': <gensim.models.keyedvectors.Vocab at 0x1bd0429b5c8>,
#  'atleast': <gensim.models.keyedvectors.Vocab at 0x1bd0429b648>,
#  'enjoyable': <gensim.models.keyedvectors.Vocab at 0x1bd0429b688>,
#  'educational': <gensim.models.keyedvectors.Vocab at 0x1bd0429b6c8>,
#  'produce': <gensim.models.keyedvectors.Vocab at 0x1bd0429b708>,
#  'hate': <gensim.models.keyedvectors.Vocab at 0x1bd0429bb48>,
#  'exciting': <gensim.models.keyedvectors.Vocab at 0x1bd0429ba48>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x1bd0429ba08>,
#  'blow': <gensim.models.keyedvectors.Vocab at 0x1bd0429b908>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x1bd0429bac8>,
#  'accomplish': <gensim.models.keyedvectors.Vocab at 0x1bd0429bbc8>,
#  'disagree': <gensim.models.keyedvectors.Vocab at 0x1bd0429bb88>,
#  'obesity': <gensim.models.keyedvectors.Vocab at 0x1bd0429b788>,
#  'cramp': <gensim.models.keyedvectors.Vocab at 0x1bd0429bc08>,
#  'sexual': <gensim.models.keyedvectors.Vocab at 0x1bd0429bd88>,
#  'harrassment': <gensim.models.keyedvectors.Vocab at 0x1bd0429bdc8>,
#  'cyber': <gensim.models.keyedvectors.Vocab at 0x1bd0429bec8>,
#  'bullying': <gensim.models.keyedvectors.Vocab at 0x1bd0429bf88>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x1bd042a5188>,
#  'entire': <gensim.models.keyedvectors.Vocab at 0x1bd042a5348>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x1bd042a5048>,
#  'pound': <gensim.models.keyedvectors.Vocab at 0x1bd042a5488>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x1bd042a5588>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x1bd042a5108>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x1bd042a51c8>,
#  'top': <gensim.models.keyedvectors.Vocab at 0x1bd042a5408>,
#  'hear': <gensim.models.keyedvectors.Vocab at 0x1bd042a50c8>,
#  'teen': <gensim.models.keyedvectors.Vocab at 0x1bd042a5508>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x1bd042a5648>,
#  'straight': <gensim.models.keyedvectors.Vocab at 0x1bd042a5608>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x1bd042a5148>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x1bd042a56c8>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x1bd042a5708>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x1bd042a5a88>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x1bd042a58c8>,
#  'anywhere': <gensim.models.keyedvectors.Vocab at 0x1bd042a5888>,
#  'goin': <gensim.models.keyedvectors.Vocab at 0x1bd042a5788>,
#  'mad': <gensim.models.keyedvectors.Vocab at 0x1bd042a5cc8>,
#  'pissed': <gensim.models.keyedvectors.Vocab at 0x1bd042a5748>,
#  'parent': <gensim.models.keyedvectors.Vocab at 0x1bd042a5b48>,
#  'third': <gensim.models.keyedvectors.Vocab at 0x1bd042a5b88>,
#  'huge': <gensim.models.keyedvectors.Vocab at 0x1bd042a5f08>,
#  'cyberbullying': <gensim.models.keyedvectors.Vocab at 0x1bd042a5dc8>,
#  'bully': <gensim.models.keyedvectors.Vocab at 0x1bd042a5c88>,
#  'realized': <gensim.models.keyedvectors.Vocab at 0x1bd042a5e88>,
#  'became': <gensim.models.keyedvectors.Vocab at 0x1bd042a59c8>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x1bd042a5d48>,
#  'stupid': <gensim.models.keyedvectors.Vocab at 0x1bd042a5f88>,
#  'god': <gensim.models.keyedvectors.Vocab at 0x1bd042a5f48>,
#  'cyberbullied': <gensim.models.keyedvectors.Vocab at 0x1bd042a5e08>,
#  'smart': <gensim.models.keyedvectors.Vocab at 0x1bd045862c8>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x1bd04586148>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x1bd045861c8>,
#  'normally': <gensim.models.keyedvectors.Vocab at 0x1bd04586108>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x1bd04586208>,
#  'act': <gensim.models.keyedvectors.Vocab at 0x1bd04586348>,
#  'big': <gensim.models.keyedvectors.Vocab at 0x1bd04586388>,
#  'joke': <gensim.models.keyedvectors.Vocab at 0x1bd04586588>,
#  'turn': <gensim.models.keyedvectors.Vocab at 0x1bd045865c8>,
#  'rot': <gensim.models.keyedvectors.Vocab at 0x1bd04586408>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x1bd04586888>,
#  'brain': <gensim.models.keyedvectors.Vocab at 0x1bd04586648>,
#  'horrible': <gensim.models.keyedvectors.Vocab at 0x1bd04586f88>,
#  'acknowledge': <gensim.models.keyedvectors.Vocab at 0x1bd043ea488>,
#  'disadvantage': <gensim.models.keyedvectors.Vocab at 0x1bd043eab88>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x1bd043ea408>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x1bd043ea6c8>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x1bd043ea148>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x1bd0443d308>,
#  'tend': <gensim.models.keyedvectors.Vocab at 0x1bd045a4a88>,
#  'forget': <gensim.models.keyedvectors.Vocab at 0x1bd045a4c08>,
#  'danger': <gensim.models.keyedvectors.Vocab at 0x1bd045a4ac8>,
#  'deadly': <gensim.models.keyedvectors.Vocab at 0x1bd045a4cc8>,
#  'television': <gensim.models.keyedvectors.Vocab at 0x1bd045a4e48>,
#  'potato': <gensim.models.keyedvectors.Vocab at 0x1bd045a4ec8>,
#  'glued': <gensim.models.keyedvectors.Vocab at 0x1bd045a4f88>,
#  'stated': <gensim.models.keyedvectors.Vocab at 0x1bd045a4708>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x1bd045a41c8>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x1bd045a44c8>,
#  'highly': <gensim.models.keyedvectors.Vocab at 0x1bd045a4c88>,
#  'stressed': <gensim.models.keyedvectors.Vocab at 0x1bd045a4748>,
#  'storm': <gensim.models.keyedvectors.Vocab at 0x1bd045a4788>,
#  'depression': <gensim.models.keyedvectors.Vocab at 0x1bd045a4308>,
#  'sink': <gensim.models.keyedvectors.Vocab at 0x1bd045a4688>,
#  'addition': <gensim.models.keyedvectors.Vocab at 0x1bd045a4988>,
#  'serious': <gensim.models.keyedvectors.Vocab at 0x1bd045a4bc8>,
#  'surprised': <gensim.models.keyedvectors.Vocab at 0x1bd045a4f08>,
#  'wing': <gensim.models.keyedvectors.Vocab at 0x1bd045a4fc8>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x1bd045a4a48>,
#  'sometime': <gensim.models.keyedvectors.Vocab at 0x1bd045a4d08>,
#  'near': <gensim.models.keyedvectors.Vocab at 0x1bd045a4d88>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x1bd045a4048>,
#  'slowly': <gensim.models.keyedvectors.Vocab at 0x1bd046180c8>,
#  'treasured': <gensim.models.keyedvectors.Vocab at 0x1bd046181c8>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x1bd04618248>,
#  'lately': <gensim.models.keyedvectors.Vocab at 0x1bd04618148>,
#  'ruining': <gensim.models.keyedvectors.Vocab at 0x1bd04618188>,
#  'absorbed': <gensim.models.keyedvectors.Vocab at 0x1bd046182c8>,
#  'drama': <gensim.models.keyedvectors.Vocab at 0x1bd046183c8>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x1bd04618408>,
#  'interaction': <gensim.models.keyedvectors.Vocab at 0x1bd04618488>,
#  'remove': <gensim.models.keyedvectors.Vocab at 0x1bd046184c8>,
#  'reality': <gensim.models.keyedvectors.Vocab at 0x1bd04618608>,
#  'enter': <gensim.models.keyedvectors.Vocab at 0x1bd046186c8>,
#  'alternate': <gensim.models.keyedvectors.Vocab at 0x1bd04618788>,
#  'bathroom': <gensim.models.keyedvectors.Vocab at 0x1bd04618808>,
#  'eat': <gensim.models.keyedvectors.Vocab at 0x1bd04618588>,
#  'resting': <gensim.models.keyedvectors.Vocab at 0x1bd04618848>,
#  'tension': <gensim.models.keyedvectors.Vocab at 0x1bd04618888>,
#  'sorrow': <gensim.models.keyedvectors.Vocab at 0x1bd04618908>,
#  'erase': <gensim.models.keyedvectors.Vocab at 0x1bd04618988>,
#  'horrifying': <gensim.models.keyedvectors.Vocab at 0x1bd04618d88>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x1bd046189c8>,
#  'memory': <gensim.models.keyedvectors.Vocab at 0x1bd04618a88>,
#  'dangerous': <gensim.models.keyedvectors.Vocab at 0x1bd04618b88>,
#  'extremely': <gensim.models.keyedvectors.Vocab at 0x1bd04618c48>,
#  'clever': <gensim.models.keyedvectors.Vocab at 0x1bd04618b48>,
#  'console': <gensim.models.keyedvectors.Vocab at 0x1bd04618cc8>,
#  'forty': <gensim.models.keyedvectors.Vocab at 0x1bd04618ac8>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x1bd04618ec8>,
#  'killer': <gensim.models.keyedvectors.Vocab at 0x1bd04618308>,
#  'waiting': <gensim.models.keyedvectors.Vocab at 0x1bd04618f08>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x1bd04618f48>,
#  'fourth': <gensim.models.keyedvectors.Vocab at 0x1bd04618fc8>,
#  'user': <gensim.models.keyedvectors.Vocab at 0x1bd04618e48>,
#  'encounter': <gensim.models.keyedvectors.Vocab at 0x1bd045ee188>,
#  'factor': <gensim.models.keyedvectors.Vocab at 0x1bd045eea08>,
#  'obease': <gensim.models.keyedvectors.Vocab at 0x1bd045ee088>,
#  'lack': <gensim.models.keyedvectors.Vocab at 0x1bd045ee7c8>,
#  'realize': <gensim.models.keyedvectors.Vocab at 0x1bd045ee888>,
#  'warming': <gensim.models.keyedvectors.Vocab at 0x1bd045ee3c8>,
#  'becomeing': <gensim.models.keyedvectors.Vocab at 0x1bd045ee148>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x1bd045ee948>,
#  'basicly': <gensim.models.keyedvectors.Vocab at 0x1bd045ee508>,
#  'couch': <gensim.models.keyedvectors.Vocab at 0x1bd045ee788>,
#  'shape': <gensim.models.keyedvectors.Vocab at 0x1bd045ee6c8>,
#  'habbit': <gensim.models.keyedvectors.Vocab at 0x1bd045ee648>,
#  'addiction': <gensim.models.keyedvectors.Vocab at 0x1bd045eecc8>,
#  'exersise': <gensim.models.keyedvectors.Vocab at 0x1bd045ee5c8>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x1bd045ee8c8>,
#  'melt': <gensim.models.keyedvectors.Vocab at 0x1bd045ee988>,
#  'half': <gensim.models.keyedvectors.Vocab at 0x1bd045eec88>,
#  'instance': <gensim.models.keyedvectors.Vocab at 0x1bd045eee08>,
#  'splitting': <gensim.models.keyedvectors.Vocab at 0x1bd045eebc8>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x1bd045eefc8>,
#  'themselfs': <gensim.models.keyedvectors.Vocab at 0x1bd045eee48>,
#  'split': <gensim.models.keyedvectors.Vocab at 0x1bd045ee908>,
#  'conclution': <gensim.models.keyedvectors.Vocab at 0x1bd045eed08>,
#  'eventually': <gensim.models.keyedvectors.Vocab at 0x1bd045eef48>,
#  'flood': <gensim.models.keyedvectors.Vocab at 0x1bd045ee0c8>,
#  'earth': <gensim.models.keyedvectors.Vocab at 0x1bd045eeec8>,
#  'unhappy': <gensim.models.keyedvectors.Vocab at 0x1bd045ee488>,
#  'ur': <gensim.models.keyedvectors.Vocab at 0x1bd045ee808>,
#  'argument': <gensim.models.keyedvectors.Vocab at 0x1bd045ee588>,
#  'reson': <gensim.models.keyedvectors.Vocab at 0x1bd045ee248>,
#  'mane': <gensim.models.keyedvectors.Vocab at 0x1bd045eeb48>,
#  'wed': <gensim.models.keyedvectors.Vocab at 0x1bd045bd3c8>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x1bd045bd048>,
#  'stuck': <gensim.models.keyedvectors.Vocab at 0x1bd045bd1c8>,
#  'plane': <gensim.models.keyedvectors.Vocab at 0x1bd045bd488>,
#  'vary': <gensim.models.keyedvectors.Vocab at 0x1bd045bd248>,
#  'boring': <gensim.models.keyedvectors.Vocab at 0x1bd045bd408>,
#  'start': <gensim.models.keyedvectors.Vocab at 0x1bd045bd888>,
#  'chart': <gensim.models.keyedvectors.Vocab at 0x1bd045bd648>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x1bd045bd4c8>,
#  'meny': <gensim.models.keyedvectors.Vocab at 0x1bd045bd8c8>,
#  'mile': <gensim.models.keyedvectors.Vocab at 0x1bd045bdbc8>,
#  'sometimes': <gensim.models.keyedvectors.Vocab at 0x1bd045bd6c8>,
#  'thrid': <gensim.models.keyedvectors.Vocab at 0x1bd045bd9c8>,
#  'peolpe': <gensim.models.keyedvectors.Vocab at 0x1bd045bdac8>,
#  'artical': <gensim.models.keyedvectors.Vocab at 0x1bd045bdb08>,
#  'didnt': <gensim.models.keyedvectors.Vocab at 0x1bd045bd608>,
#  'writer': <gensim.models.keyedvectors.Vocab at 0x1bd045bdb88>,
#  'harder': <gensim.models.keyedvectors.Vocab at 0x1bd045bd188>,
#  'whe': <gensim.models.keyedvectors.Vocab at 0x1bd045bd988>,
#  'thinking': <gensim.models.keyedvectors.Vocab at 0x1bd045bddc8>,
#  'agen': <gensim.models.keyedvectors.Vocab at 0x1bd045bdf88>,
#  'plea': <gensim.models.keyedvectors.Vocab at 0x1bd045bdd48>,
#  'resons': <gensim.models.keyedvectors.Vocab at 0x1bd045bdcc8>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x1bd045bd388>,
#  'detailed': <gensim.models.keyedvectors.Vocab at 0x1bd045bde08>,
#  'persuade': <gensim.models.keyedvectors.Vocab at 0x1bd045bd088>,
#  'yor': <gensim.models.keyedvectors.Vocab at 0x1bd045bd288>,
#  'wast': <gensim.models.keyedvectors.Vocab at 0x1bd045bde48>,
#  'fat': <gensim.models.keyedvectors.Vocab at 0x1bd045bdd08>,
#  'insted': <gensim.models.keyedvectors.Vocab at 0x1bd045bdf48>,
#  'girlfriend': <gensim.models.keyedvectors.Vocab at 0x1bd045bd948>,
#  'wach': <gensim.models.keyedvectors.Vocab at 0x1bd045bd808>,
#  'stuff': <gensim.models.keyedvectors.Vocab at 0x1bd045bd708>,
#  'adult': <gensim.models.keyedvectors.Vocab at 0x1bd045bd508>,
#  'becasue': <gensim.models.keyedvectors.Vocab at 0x1bd045aca88>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x1bd045ac648>,
#  'ba': <gensim.models.keyedvectors.Vocab at 0x1bd045acac8>,
#  'porn': <gensim.models.keyedvectors.Vocab at 0x1bd045accc8>,
#  'mainly': <gensim.models.keyedvectors.Vocab at 0x1bd045ac108>,
#  'addicted': <gensim.models.keyedvectors.Vocab at 0x1bd045acb88>,
#  'organize': <gensim.models.keyedvectors.Vocab at 0x1bd045ac2c8>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x1bd045ac888>,
#  'clearly': <gensim.models.keyedvectors.Vocab at 0x1bd045ac048>,
#  'relly': <gensim.models.keyedvectors.Vocab at 0x1bd045ac188>,
#  'staff': <gensim.models.keyedvectors.Vocab at 0x1bd045ac248>,
#  'se': <gensim.models.keyedvectors.Vocab at 0x1bd045ac288>,
#  'useing': <gensim.models.keyedvectors.Vocab at 0x1bd045acb08>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x1bd045ac408>,
#  'biggest': <gensim.models.keyedvectors.Vocab at 0x1bd045ac348>,
#  'knowledge': <gensim.models.keyedvectors.Vocab at 0x1bd045ace48>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x1bd045acd48>,
#  'front': <gensim.models.keyedvectors.Vocab at 0x1bd045ace08>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x1bd045acd88>,
#  'ten': <gensim.models.keyedvectors.Vocab at 0x1bd045ac988>,
#  'putting': <gensim.models.keyedvectors.Vocab at 0x1bd045ac788>,
#  'webchat': <gensim.models.keyedvectors.Vocab at 0x1bd045ace88>,
#  'touch': <gensim.models.keyedvectors.Vocab at 0x1bd045aca48>,
#  'image': <gensim.models.keyedvectors.Vocab at 0x1bd045ac748>,
#  'blonde': <gensim.models.keyedvectors.Vocab at 0x1bd045ac208>,
#  'haired': <gensim.models.keyedvectors.Vocab at 0x1bd045ac308>,
#  'filled': <gensim.models.keyedvectors.Vocab at 0x1bd045ac808>,
#  'thanks': <gensim.models.keyedvectors.Vocab at 0x1bd045ac6c8>,
#  'actual': <gensim.models.keyedvectors.Vocab at 0x1bd045aca08>,
#  'explaining': <gensim.models.keyedvectors.Vocab at 0x1bd045acf48>,
#  'priceless': <gensim.models.keyedvectors.Vocab at 0x1bd045ac948>,
#  'soceity': <gensim.models.keyedvectors.Vocab at 0x1bd0459f588>,
#  'wish': <gensim.models.keyedvectors.Vocab at 0x1bd0459f048>,
#  'expand': <gensim.models.keyedvectors.Vocab at 0x1bd0459f448>,
#  'supported': <gensim.models.keyedvectors.Vocab at 0x1bd0459f148>,
#  'firstly': <gensim.models.keyedvectors.Vocab at 0x1bd0459f308>,
#  'excel': <gensim.models.keyedvectors.Vocab at 0x1bd0459f208>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x1bd0459f348>,
#  'improves': <gensim.models.keyedvectors.Vocab at 0x1bd0459f408>,
#  'simple': <gensim.models.keyedvectors.Vocab at 0x1bd0459f648>,
#  'tying': <gensim.models.keyedvectors.Vocab at 0x1bd0459f688>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x1bd0459fa08>,
#  'famous': <gensim.models.keyedvectors.Vocab at 0x1bd0459fa48>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x1bd0459f888>,
#  'strength': <gensim.models.keyedvectors.Vocab at 0x1bd0459fac8>,
#  'automatically': <gensim.models.keyedvectors.Vocab at 0x1bd0459fc08>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x1bd0459f748>,
#  'command': <gensim.models.keyedvectors.Vocab at 0x1bd0459fcc8>,
#  'basketball': <gensim.models.keyedvectors.Vocab at 0x1bd0459fe88>,
#  'wan': <gensim.models.keyedvectors.Vocab at 0x1bd0459fc48>,
#  'decreasing': <gensim.models.keyedvectors.Vocab at 0x1bd0459ff08>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x1bd0459f388>,
#  'presented': <gensim.models.keyedvectors.Vocab at 0x1bd0459f908>,
#  'link': <gensim.models.keyedvectors.Vocab at 0x1bd0459fb08>,
#  'countless': <gensim.models.keyedvectors.Vocab at 0x1bd0459f8c8>,
#  'peole': <gensim.models.keyedvectors.Vocab at 0x1bd0459fd48>,
#  'increase': <gensim.models.keyedvectors.Vocab at 0x1bd0459fd08>,
#  'tolerance': <gensim.models.keyedvectors.Vocab at 0x1bd0459f248>,
#  'resourceful': <gensim.models.keyedvectors.Vocab at 0x1bd0459ff48>,
#  'aspect': <gensim.models.keyedvectors.Vocab at 0x1bd0459fe48>,
#  'bring': <gensim.models.keyedvectors.Vocab at 0x1bd0459f188>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x1bd0459f5c8>,
#  'happend': <gensim.models.keyedvectors.Vocab at 0x1bd0459f7c8>,
#  'citizen': <gensim.models.keyedvectors.Vocab at 0x1bd0459f808>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x1bd04614048>,
#  'expensive': <gensim.models.keyedvectors.Vocab at 0x1bd04614108>,
#  'bill': <gensim.models.keyedvectors.Vocab at 0x1bd04614188>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x1bd04614248>,
#  'visit': <gensim.models.keyedvectors.Vocab at 0x1bd04614308>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x1bd04614388>,
#  'aid': <gensim.models.keyedvectors.Vocab at 0x1bd046143c8>,
#  'era': <gensim.models.keyedvectors.Vocab at 0x1bd04614408>,
#  'advancement': <gensim.models.keyedvectors.Vocab at 0x1bd04614548>,
#  'push': <gensim.models.keyedvectors.Vocab at 0x1bd046149c8>,
#  'handeye': <gensim.models.keyedvectors.Vocab at 0x1bd04614dc8>,
#  'unified': <gensim.models.keyedvectors.Vocab at 0x1bd04614488>,
#  'scare': <gensim.models.keyedvectors.Vocab at 0x1bd04614708>,
#  'nobody': <gensim.models.keyedvectors.Vocab at 0x1bd04614508>,
#  'slower': <gensim.models.keyedvectors.Vocab at 0x1bd046146c8>,
#  'belive': <gensim.models.keyedvectors.Vocab at 0x1bd04614908>,
#  'unhealthy': <gensim.models.keyedvectors.Vocab at 0x1bd04614a48>,
#  'score': <gensim.models.keyedvectors.Vocab at 0x1bd04614bc8>,
#  'beauty': <gensim.models.keyedvectors.Vocab at 0x1bd04614c08>,
#  'waste': <gensim.models.keyedvectors.Vocab at 0x1bd04614e88>,
#  'hanging': <gensim.models.keyedvectors.Vocab at 0x1bd04614d88>,
#  'boost': <gensim.models.keyedvectors.Vocab at 0x1bd04614cc8>,
#  'brings': <gensim.models.keyedvectors.Vocab at 0x1bd04614848>,
#  'fine': <gensim.models.keyedvectors.Vocab at 0x1bd04614d08>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x1bd04614f08>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x1bd04614fc8>,
#  'hobby': <gensim.models.keyedvectors.Vocab at 0x1bd046147c8>,
#  'admit': <gensim.models.keyedvectors.Vocab at 0x1bd04614608>,
#  'stay': <gensim.models.keyedvectors.Vocab at 0x1bd04614648>,
#  'relax': <gensim.models.keyedvectors.Vocab at 0x1bd04614a88>,
#  'checking': <gensim.models.keyedvectors.Vocab at 0x1bd04614b48>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x1bd04614ac8>,
#  'hungry': <gensim.models.keyedvectors.Vocab at 0x1bd037d4e48>,
#  'snack': <gensim.models.keyedvectors.Vocab at 0x1bd04630048>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x1bd046302c8>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x1bd04630148>,
#  'jump': <gensim.models.keyedvectors.Vocab at 0x1bd04630208>,
#  'pop': <gensim.models.keyedvectors.Vocab at 0x1bd04630248>,
#  'corn': <gensim.models.keyedvectors.Vocab at 0x1bd04630088>,
#  'nap': <gensim.models.keyedvectors.Vocab at 0x1bd04630288>,
#  'dependable': <gensim.models.keyedvectors.Vocab at 0x1bd04630308>,
#  'selected': <gensim.models.keyedvectors.Vocab at 0x1bd04630388>,
#  'thats': <gensim.models.keyedvectors.Vocab at 0x1bd04630408>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x1bd04630448>,
#  'gon': <gensim.models.keyedvectors.Vocab at 0x1bd04630188>,
#  'na': <gensim.models.keyedvectors.Vocab at 0x1bd0462d4c8>,
#  'tomorrow': <gensim.models.keyedvectors.Vocab at 0x1bd0462d508>,
#  'promised': <gensim.models.keyedvectors.Vocab at 0x1bd0462de88>,
#  'chance': <gensim.models.keyedvectors.Vocab at 0x1bd0462d5c8>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x1bd0462d088>,
#  'balance': <gensim.models.keyedvectors.Vocab at 0x1bd0462d0c8>,
#  'fined': <gensim.models.keyedvectors.Vocab at 0x1bd0462d108>,
#  'ot': <gensim.models.keyedvectors.Vocab at 0x1bd0462d148>,
#  'moon': <gensim.models.keyedvectors.Vocab at 0x1bd0462d188>,
#  'realy': <gensim.models.keyedvectors.Vocab at 0x1bd0462d208>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x1bd0462d288>,
#  'create': <gensim.models.keyedvectors.Vocab at 0x1bd0462d308>,
#  'shirt': <gensim.models.keyedvectors.Vocab at 0x1bd0462d348>,
#  'creative': <gensim.models.keyedvectors.Vocab at 0x1bd0462d888>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x1bd0462dd08>,
#  'apartment': <gensim.models.keyedvectors.Vocab at 0x1bd0462d408>,
#  'fill': <gensim.models.keyedvectors.Vocab at 0x1bd0462d7c8>,
#  'application': <gensim.models.keyedvectors.Vocab at 0x1bd0462d708>,
#  'trip': <gensim.models.keyedvectors.Vocab at 0x1bd0462dc08>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x1bd0462d648>,
#  'im': <gensim.models.keyedvectors.Vocab at 0x1bd0462d448>,
#  'regular': <gensim.models.keyedvectors.Vocab at 0x1bd0462d9c8>,
#  'rich': <gensim.models.keyedvectors.Vocab at 0x1bd0462dac8>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x1bd0462d808>,
#  'super': <gensim.models.keyedvectors.Vocab at 0x1bd0462db88>,
#  'address': <gensim.models.keyedvectors.Vocab at 0x1bd0462dc48>,
#  'discovery': <gensim.models.keyedvectors.Vocab at 0x1bd0462df08>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x1bd0462dcc8>,
#  'harmful': <gensim.models.keyedvectors.Vocab at 0x1bd0462d988>,
#  'convince': <gensim.models.keyedvectors.Vocab at 0x1bd0462dd88>,
#  'advancing': <gensim.models.keyedvectors.Vocab at 0x1bd0462de08>,
#  'rapidly': <gensim.models.keyedvectors.Vocab at 0x1bd0462df88>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x1bd0462de48>,
#  'discovered': <gensim.models.keyedvectors.Vocab at 0x1bd037d7ec8>,
#  'died': <gensim.models.keyedvectors.Vocab at 0x1bd037d7ac8>,
#  'increased': <gensim.models.keyedvectors.Vocab at 0x1bd037d7d08>,
#  'medical': <gensim.models.keyedvectors.Vocab at 0x1bd037d7348>,
#  'cave': <gensim.models.keyedvectors.Vocab at 0x1bd037d7308>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x1bd037d7548>,
#  'finnaly': <gensim.models.keyedvectors.Vocab at 0x1bd037e0b48>,
#  'speed': <gensim.models.keyedvectors.Vocab at 0x1bd037e07c8>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x1bd037e0588>,
#  'household': <gensim.models.keyedvectors.Vocab at 0x1bd037e0708>,
#  'object': <gensim.models.keyedvectors.Vocab at 0x1bd037e4108>,
#  'bored': <gensim.models.keyedvectors.Vocab at 0x1bd037e41c8>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x1bd037e45c8>,
#  'rainy': <gensim.models.keyedvectors.Vocab at 0x1bd037e4908>,
#  'chilly': <gensim.models.keyedvectors.Vocab at 0x1bd037e4c48>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x1bd037e4d88>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x1bd037e4e48>,
#  'networking': <gensim.models.keyedvectors.Vocab at 0x1bd037ddac8>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x1bd037dda08>,
#  'network': <gensim.models.keyedvectors.Vocab at 0x1bd037dd708>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x1bd037dd9c8>,
#  'youtube': <gensim.models.keyedvectors.Vocab at 0x1bd037ddd88>,
#  'economic': <gensim.models.keyedvectors.Vocab at 0x1bd037ddf48>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x1bd037dd848>,
#  'rescue': <gensim.models.keyedvectors.Vocab at 0x1bd037dd3c8>,
#  'yet': <gensim.models.keyedvectors.Vocab at 0x1bd037eb088>,
#  'twice': <gensim.models.keyedvectors.Vocab at 0x1bd037eb188>,
#  'microsoft': <gensim.models.keyedvectors.Vocab at 0x1bd037eb388>,
#  'effort': <gensim.models.keyedvectors.Vocab at 0x1bd037eb5c8>,
#  'listen': <gensim.models.keyedvectors.Vocab at 0x1bd037eb748>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x1bd037eb908>,
#  'chating': <gensim.models.keyedvectors.Vocab at 0x1bd037eb988>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x1bd037ebb08>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x1bd037ebbc8>,
#  'exersice': <gensim.models.keyedvectors.Vocab at 0x1bd037eb888>,
#  'essential': <gensim.models.keyedvectors.Vocab at 0x1bd037ebc48>,
#  'highest': <gensim.models.keyedvectors.Vocab at 0x1bd037ebc88>,
#  'compared': <gensim.models.keyedvectors.Vocab at 0x1bd037ebe88>,
#  'overweight': <gensim.models.keyedvectors.Vocab at 0x1bd037ebfc8>,
#  'develope': <gensim.models.keyedvectors.Vocab at 0x1bd037e7a88>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x1bd037e7c08>,
#  'blood': <gensim.models.keyedvectors.Vocab at 0x1bd037e7208>,
#  'bike': <gensim.models.keyedvectors.Vocab at 0x1bd037e7508>,
#  'jog': <gensim.models.keyedvectors.Vocab at 0x1bd037e7d88>,
#  'reduce': <gensim.models.keyedvectors.Vocab at 0x1bd04621f88>,
#  'ran': <gensim.models.keyedvectors.Vocab at 0x1bd046219c8>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x1bd04621c88>,
#  'island': <gensim.models.keyedvectors.Vocab at 0x1bd04621388>,
#  'allowing': <gensim.models.keyedvectors.Vocab at 0x1bd046210c8>,
#  'interest': <gensim.models.keyedvectors.Vocab at 0x1bd04621208>,
#  'account': <gensim.models.keyedvectors.Vocab at 0x1bd046212c8>,
#  'personal': <gensim.models.keyedvectors.Vocab at 0x1bd04621608>,
#  'posted': <gensim.models.keyedvectors.Vocab at 0x1bd04621348>,
#  'info': <gensim.models.keyedvectors.Vocab at 0x1bd04621148>,
#  'crime': <gensim.models.keyedvectors.Vocab at 0x1bd04621448>,
#  'creates': <gensim.models.keyedvectors.Vocab at 0x1bd046215c8>,
#  'possibly': <gensim.models.keyedvectors.Vocab at 0x1bd04621788>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x1bd046214c8>,
#  'suicide': <gensim.models.keyedvectors.Vocab at 0x1bd04621508>,
#  'closer': <gensim.models.keyedvectors.Vocab at 0x1bd04621b88>,
#  'safer': <gensim.models.keyedvectors.Vocab at 0x1bd04621808>,
#  'explore': <gensim.models.keyedvectors.Vocab at 0x1bd046218c8>,
#  'solve': <gensim.models.keyedvectors.Vocab at 0x1bd04621988>,
#  'real': <gensim.models.keyedvectors.Vocab at 0x1bd04621a48>,
#  'solution': <gensim.models.keyedvectors.Vocab at 0x1bd04621b48>,
#  'teaching': <gensim.models.keyedvectors.Vocab at 0x1bd04621cc8>,
#  'basically': <gensim.models.keyedvectors.Vocab at 0x1bd04621d88>,
#  'born': <gensim.models.keyedvectors.Vocab at 0x1bd04621e48>,
#  'average': <gensim.models.keyedvectors.Vocab at 0x1bd04621d48>,
#  'tye': <gensim.models.keyedvectors.Vocab at 0x1bd04621688>,
#  'instrument': <gensim.models.keyedvectors.Vocab at 0x1bd04621ec8>,
#  'chore': <gensim.models.keyedvectors.Vocab at 0x1bd04621c08>,
#  'throw': <gensim.models.keyedvectors.Vocab at 0x1bd046216c8>,
#  ...}

# %%
vec['dear']
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 0.05507124, -0.57404244, -2.1236284 ,  2.1481616 ,  1.1486664 ,
#        -0.38436928, -1.1930691 ,  0.7938984 , -1.0582592 , -0.76002663,
#         0.82205945, -0.7639695 , -0.91305566, -2.1619873 ,  2.0387795 ,
#         1.3983226 , -0.32995537, -1.2885841 ,  1.6247355 , -3.1107125 ,
#         1.2497758 ,  1.0077168 , -1.4004478 ,  0.5205935 ,  0.9477795 ,
#        -1.2932314 , -0.5309005 , -2.4648468 ,  0.3570563 ,  2.3643563 ,
#        -1.5367496 ,  0.2539195 , -1.3557298 , -0.14220917, -0.649685  ,
#        -0.19502404, -1.3714997 , -1.2523214 ,  2.736435  , -1.3496289 ,
#        -0.47780353,  0.8633374 , -0.2804938 ,  0.57324386, -0.5073209 ,
#        -0.69269645, -0.377241  ,  1.1540724 ,  0.3934464 ,  0.333351  ,
#         0.3155654 , -0.65767205, -0.52224433, -0.16823965, -0.41854784,
#         0.97287184,  0.19560811,  0.10124855,  1.5187714 ,  0.9385061 ,
#        -0.29709023,  0.48454416,  0.27507886,  0.4039023 ,  0.5495643 ,
#         0.22860512,  0.57777137, -0.9883676 ,  0.6480119 ,  0.7085752 ,
#        -0.7846557 , -0.05828083,  0.96519226, -1.7456789 , -1.0838355 ,
#        -0.13504133,  1.7694461 , -0.79298514, -1.020043  ,  0.8482857 ,
#        -0.24472128, -0.37802026, -0.2783857 ,  0.4058655 ,  0.47454432,
#         1.3784119 , -0.19418456,  0.08841322,  0.5885967 , -0.022484  ,
#         0.58362454, -0.3233211 ,  1.4507769 ,  0.22595581,  0.5559819 ,
#        -1.339793  , -0.7828452 ,  0.6315768 ,  0.10496662, -0.84907025,
#         0.48004103, -1.3826619 , -0.82308555, -0.733702  ,  0.10914281,
#         1.2457252 , -0.01200084,  0.30738518,  0.710903  ,  0.3293284 ,
#        -1.0780481 , -1.4707307 , -0.81058866, -0.19504716, -1.5624745 ,
#         0.38026085, -0.11801389,  0.07626041, -0.11019307, -1.4934564 ,
#         1.0449784 , -0.3911612 , -1.9704756 , -0.6404142 ,  1.3552204 ,
#         0.29578567,  1.3143624 ,  0.10487869,  1.2027117 , -1.0772169 ,
#        -0.63587064, -1.0708764 , -0.2089008 , -0.22218505,  0.5641784 ,
#        -1.6817309 , -0.09287321,  2.2484562 , -0.6067759 , -1.3370093 ,
#         1.1069374 , -0.24979828, -0.9467502 ,  2.241862  ,  1.9192196 ,
#         0.27225998, -0.33544677,  1.267163  , -2.2957988 , -0.02697676],
#       dtype=float32)

# %%
def makeFeatureVec(words, model, num_features):
    """Make Feature Vector from the words list of an Essay."""
    featureVec = np.zeros((num_features,))
    num_words = 0.
    index2word_set = set(model.wv.index2word)
    for word in words:
        if word in index2word_set:
            num_words += 1
            featureVec = np.add(featureVec,model[word])        
    featureVec = np.divide(featureVec,num_words)
    return featureVec

def getAvgFeatureVecs(essays, model, num_features):
    """Main function to generate the word vectors for word2vec model."""
    counter = 0
    essayFeatureVecs = np.zeros((len(essays),num_features))
    for essay in essays:
        essayFeatureVecs[counter] = makeFeatureVec(essay, model, num_features)
        counter = counter + 1
    return essayFeatureVecs

# %%
final_X = getAvgFeatureVecs(word, vec, num_features)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':

# %%
final_X
# Out:
# array([[ 0.18242029,  0.33923656,  0.26098029, ..., -0.02968219,
#         -0.07837768,  0.4356697 ],
#        [ 0.05108483,  0.36870425,  0.07579173, ..., -0.21773472,
#         -0.00979356,  0.41006652],
#        [ 0.02194581,  0.18249852, -0.00491926, ..., -0.00802658,
#         -0.06918276,  0.33210004],
#        ...,
#        [ 0.24565808,  0.31499432,  0.16860829, ...,  0.00145448,
#         -0.02487484, -0.03660882],
#        [ 0.14494165,  0.27025834,  0.25117121, ...,  0.03491832,
#          0.01277465, -0.10691901],
#        [ 0.12533526,  0.29602973,  0.3825591 , ...,  0.15060224,
#         -0.15690097,  0.04885805]])

# %%
len(final_X), len(final_X[0])
# Out:
# (12978, 150)

# %%
final_X.shape
# Out:
# (12978, 150)

# %%
# Splitting into train and test set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(final_X, y, test_size=0.2)

# %%
len(X_train), len(y_train)
# Out:
# (10382, 10382)

# %%
len(X_test), len(y_test)
# Out:
# (2596, 2596)

# %%
# Reshaping X

# %%
X_train = np.reshape(X_train,(X_train.shape[0],1,X_train.shape[1]))
X_test = np.reshape(X_test,(X_test.shape[0],1,X_test.shape[1]))

# %%
X_train.shape, X_test.shape
# Out:
# ((10382, 1, 150), (2596, 1, 150))

# %%
# Building the LSTM model

# %%
model = keras.models.Sequential([
    keras.layers.LSTM(150, dropout=0.4, recurrent_dropout=0.4, input_shape=[1, 150], return_sequences=True),
    keras.layers.LSTM(64, recurrent_dropout=0.4),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1,activation='relu')
])

# %%
model.compile(loss='mean_squared_error', optimizer='rmsprop', metrics=['mae'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 1, 150)            180600
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 64)                55040
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 235,705
# Trainable params: 235,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=15,batch_size=64)
# Out:
# Train on 10382 samples, validate on 2596 samples
# Epoch 1/15
# 10382/10382 [==============================] - 1s 131us/step - loss: 63.3629 - mae: 4.2623 - val_loss: 43.8870 - val_mae: 3.5048
# Epoch 2/15
# 10382/10382 [==============================] - 1s 81us/step - loss: 37.2914 - mae: 3.0984 - val_loss: 27.1291 - val_mae: 2.4149
# Epoch 3/15
# 10382/10382 [==============================] - 1s 78us/step - loss: 27.3962 - mae: 2.6311 - val_loss: 20.6621 - val_mae: 2.1977
# Epoch 4/15
# 10382/10382 [==============================] - 1s 72us/step - loss: 21.9607 - mae: 2.4067 - val_loss: 14.5697 - val_mae: 1.8852
# Epoch 5/15
# 10382/10382 [==============================] - 1s 71us/step - loss: 17.1990 - mae: 2.2092 - val_loss: 11.0430 - val_mae: 1.7324
# Epoch 6/15
# 10382/10382 [==============================] - 1s 71us/step - loss: 14.1588 - mae: 2.0415 - val_loss: 8.6171 - val_mae: 1.5757
# Epoch 7/15
# 10382/10382 [==============================] - 1s 77us/step - loss: 13.0024 - mae: 1.9524 - val_loss: 7.5048 - val_mae: 1.4890
# Epoch 8/15
# 10382/10382 [==============================] - 1s 72us/step - loss: 11.7333 - mae: 1.8838 - val_loss: 7.0526 - val_mae: 1.4855
# Epoch 9/15
# 10382/10382 [==============================] - 1s 78us/step - loss: 11.8401 - mae: 1.8522 - val_loss: 6.6217 - val_mae: 1.4112
# Epoch 10/15
# 10382/10382 [==============================] - 1s 89us/step - loss: 10.9341 - mae: 1.8074 - val_loss: 6.5969 - val_mae: 1.4075
# Epoch 11/15
# 10382/10382 [==============================] - 1s 69us/step - loss: 11.1268 - mae: 1.7774 - val_loss: 6.1390 - val_mae: 1.3401
# Epoch 12/15
# 10382/10382 [==============================] - 1s 81us/step - loss: 10.5017 - mae: 1.7544 - val_loss: 6.3570 - val_mae: 1.3610
# Epoch 13/15
# 10382/10382 [==============================] - 1s 65us/step - loss: 9.8588 - mae: 1.7114 - val_loss: 5.9726 - val_mae: 1.3262
# Epoch 14/15
# 10382/10382 [==============================] - 1s 90us/step - loss: 10.1310 - mae: 1.7045 - val_loss: 6.1564 - val_mae: 1.3424
# Epoch 15/15
# 10382/10382 [==============================] - 1s 67us/step - loss: 10.1421 - mae: 1.7034 - val_loss: 6.2968 - val_mae: 1.3478

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([[2.006921 ],
#        [2.5693684],
#        [2.011354 ],
#        ...,
#        [1.8839948],
#        [2.0064695],
#        [8.25703  ]], dtype=float32)

# %%
y_test.shape, y_pred.shape
# Out:
# ((2596,), (2596, 1))

# %%
# Checking kappa score

# %%
from sklearn.metrics import cohen_kappa_score

# %%
result = cohen_kappa_score(y_test,np.round(y_pred),weights='quadratic')
result
# Out:
# 0.9595757968460387

# %%
# Saving word2vec model

# %%
from gensim.models import Word2Vec

# %%
vec.wv.save_word2vec_format('word2vecmodel.bin', binary=True)

# %%
# Saving lstm model

# %%
model.save('lstmmodel.h5')
